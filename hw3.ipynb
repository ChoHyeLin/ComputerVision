# %% [markdown]
# # HW3

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
src = cv2.imread('coin1.jpg')
gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
blr = cv2.GaussianBlur(gray, (0, 0), 1)

gray_blur = cv2.GaussianBlur(gray, (15, 15), 0)
th3 =cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
cv2.THRESH_BINARY_INV, 11, 1)

images = [th3]

plt.figure(figsize=(20,15))
for i in range(1):
    plt.subplot(2,2,i+1),plt.imshow(images[i])
    plt.xticks([]),plt.yticks([])
plt.show()

cv2.imshow('image',th3)
cv2.imshow('image1',src)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
src = cv2.imread('coin2.jpg')
gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
blr = cv2.GaussianBlur(gray, (0, 0), 1)

gray_blur = cv2.GaussianBlur(gray, (15, 15), 0)
th3 =cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
cv2.THRESH_BINARY_INV, 11, 1)

images = [th3]

plt.figure(figsize=(20,15))
for i in range(1):
    plt.subplot(2,2,i+1),plt.imshow(images[i])
    plt.xticks([]),plt.yticks([])
plt.show()

cv2.imshow('image',th3)
cv2.imshow('image1',src)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
src = cv2.imread('coin3.jpg')
gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
blr = cv2.GaussianBlur(gray, (0, 0), 1)

gray_blur = cv2.GaussianBlur(gray, (15, 15), 0)
th3 =cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
cv2.THRESH_BINARY_INV, 11, 1)

images = [th3]

plt.figure(figsize=(20,15))
for i in range(1):
    plt.subplot(2,2,i+1),plt.imshow(images[i])
    plt.xticks([]),plt.yticks([])
plt.show()

cv2.imshow('image',th3)
cv2.imshow('image1',src)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
src = cv2.imread('coin4.jpg')
gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
blr = cv2.GaussianBlur(gray, (0, 0), 1)

gray_blur = cv2.GaussianBlur(gray, (15, 15), 0)
th3 =cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
cv2.THRESH_BINARY_INV, 11, 1)
    
images = [th3]

plt.figure(figsize=(20,15))
for i in range(1):
    plt.subplot(2,2,i+1),plt.imshow(images[i])
    plt.xticks([]),plt.yticks([])
plt.show()

cv2.imshow('image',th3)
cv2.imshow('image1',src)
cv2.waitKey(0)
cv2.destroyAllWindows()
